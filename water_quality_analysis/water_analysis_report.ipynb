# %% [markdown]
# # Final Environmental Water Analysis Report

# %% [markdown]
# ## 1. Executive Summary
# The dataset represents Zimbabwe water samples obtained from three different sources namely river, borehole and the dam in the 8 provinces of Zimbabwe
# From the analysis of the data it was very clear that most of these sources did not have safe and clean water for  either human usage and animal habitant.
# the regions with the highest conatmination were
#
# ### Key findings
# + The highest contaminated water came from the rivers, with 155 samples out of the 400 analysed being unsafe for human consumption.
# + Dams had the fewest contaminated samples.
# + The provinces\regions with the most contaminated or unsafe water were Manicaland, Mashonaland and Masvingo with all samples coming out unsafe.
# + Harare had the highest number of samples that are clean.
# + However despite the presence of safe water source per region, the samples had a 95% rate of pollution and only 5% of the samples being safe.
# + Regions with highest contamination
# + Therefore, overall safety status is unsafe, there is need for further purification processes to be imployed before using the water for human consumption

# %% [markdown]
# # 2. Introduction
#
# ## Purpose of this analysis
# + The main aim of this analysis was to ascertain the quality of water from 3 different sources in all the provinces of Zimbawe to ensure that the community has access to clean water
#
# ## Why water quality matters
# + Water quality is important for public safety, environmental protection, and economic growth.
# + crucial for water resource management, planning and decision making.
# + Disease prevention
# ## Parameters assessed:
# + pH
# + Nitrates
# + Dissolved oxygen
# + Electrical conductivity
# + Turbidity

# %% [markdown]
# # 3. Methods
#
# ### 3.1 Data cleaning
#
# + Handling missing values
#
# + Creating categories (pH_category, turbidity_category, EC, DO, nitrates)
#
# ### 3.2 Water Status Classification
#
# #### Simple rule:
# + UNSAFE if any test exceeds limits.
#
# ### 3.3 Outlier Detection
#
# + Criteria used (pH < 5.8 or > 9, turbidity > 120, nitrates > 25, EC > 1400).

# %% [markdown]
# ### Unsafe Samples per Region
# This plot shows the number of unsafe water samples identified in each region.
#
# ![Unsafe Samples per Region](images/unsafe_samples_region.png)

# %% [markdown]
# ### Percentage of Unsafe Samples per Region
# This chart displays the proportion of unsafe samples per region, helping identify hotspots.
#
# ![Percentage Unsafe per Region](images/percentage_unsafe_per_region.png)

# %% [markdown]
# ### Pollution Rate by Source Type
# This visual compares pollution levels across different source categories (rivers, dams, boreholes).
#
# ![Pollution Rate by Source Type](images/pollution_rate_by_source_type.png)

# %% [markdown]
# ### Pollution Rate by Water Source
# This chart highlights the unsafe percentage for each specific water source.
#
# ![Pollution Rate by Water Source](images/pollution_rate_by_source.png)

# %% [markdown]
# ### Safe vs Unsafe Samples by Water Source
# This shows which water sources contribute most to safe or unsafe samples.
#
# ![Safe vs Unsafe by Water Source](images/safe_vs_unsafe_by_water_source.png)

# %% [markdown]
# ### Water Properties Dashboard
# This figure visualizes all six water-quality parameters together.
#
# ![Water Properties Dashboard](images/water_properties.png)

# %%
import pandas as pd

path = r"C:\Users\mdumiseni\OneDrive\Documents\data science assignements\data-science-portfolio\water_quality_analysis"  # adjust if needed

# %% [markdown]
# ### Region Water Status Summary
# This table shows the number of SAFE and UNSAFE samples recorded in each region.
#
# `region_status.csv`

# %%
region_status = pd.read_csv(path + "region_status.csv")
region_status
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 region_status = pd.read_csv(path + "region_status.csv")
#       2 region_status
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# ### Water Source Status Summary
# This table summarizes safe vs unsafe samples for each individual water source.
#
# `water_source_status.csv`

# %% [markdown]
# ### Outliers per Region
# This table lists the number of extreme-value samples (pH, turbidity, nitrates, etc.) from each region.
#
# `outliers_per_region.csv`

# %% [markdown]
# ### Outliers per Water Source
# This table identifies which water sources produced extreme readings.
#
# `outliers_per_water_source.csv`

# %% [markdown]
# ### Extreme Value Heatmap Table (Region × Water Source)
# This pivot table shows where extreme water values occurred across regions and sources.
#
# `outliers_region_source_pivot.csv`

# %% [markdown]
# ### Cleaned Water Dataset (Final Processed Data)
# This is the final cleaned dataset used for all analysis and visualizations.
#
# `cleaned_water_dataset.csv`

# %% [markdown]
# # 5. Interpretation and Discussion
#
# **Which regions are most polluted?**
# + The regions most polluted are Manicaland, Mashonaland Centrala and Msvingo, with all samples of the 3 different sources being contaminated and deemed unsafe
# + However the remaning 6 regions also show a high rate of polluted water.
#
# **Which water sources pose the highest risk?**
#
# + The water sources with the  highest risk is the River, however all the water sources pose a high risk as the pollution rate is above 95% in all water sources.
#
# **What factors might explain these trends?**
#
# + Most or almost all water samples by region and water source show that they are affected by several propeties leading to the water being unsafe for human and aquaticv life.
# + Most samples, more than 200 samples had basic pH, very high turbidity and high levels of nitrates present hence due to these offsetting figures the water was labelled unsafe.
#
# **Any patterns that indicate agricultural runoff, industrial discharge**
#
# + the presence of high levels of nitrates show that there is huge amounts of fertiliser runoff coming from the farming sector around these water sources all across the regions.
# + however most samples showed normal levels of dissolved oxygen, showing the water's capability of keeping aquatic life, however the high levels of nitrates pose threaat to this aquatic life.

# %% [markdown]
# # 6. Recommendations
#
# + Monitor regions with high unsafe percentages
#
# + Treat highly polluted water sources
#
# + Further sampling recommended for hotspot regions
#
# **Possible causes and next steps**
# + high agricultural runoff hence suggest use of bio friendly alternatives to fertilisers such as manure and mulch
#
# # 7. Conclusion
# + There is need to seriously invest in water purification techniques and processes to ensure communities are provided with fresh and clean water
# + There is need to invest in natural alternatives to fertilisers such as manure and mulch to ensure that the aquatic life is not destroyed.
