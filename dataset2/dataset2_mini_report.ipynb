# %% [markdown]
# # Week 1 Data set 2 : herbal analysis

# %% [markdown]
# #Mini Report — Dataset 2: Herbal Plant Samples
# 1. **Dataset Overview**
#
# Number of samples: 120
#
# Species included:
#
# ***Mentha spicata***
#
# ***Rosmarinus officinalis***
#
# ***Lavandula angustifolia***
#
# ***Curcuma longa***
#
# Sample types: leaf, root, stem, flower
#
# Variables: weight_mg, pH, sample_type, pH_category, weight_grams
#
# 2. **pH Distribution**
#
# Acidic samples: 70
#
# Neutral samples: 21
#
# Basic samples: 29
#
# Sample type with the highest acidic count: root
#
# **Brief interpretation:**
#
#  "Root samples showed a higher proportion of acidic readings, suggesting possible biochemical variation and composition in extraction mixtures."
#
# 3. **Weight Analysis**
#
# Species with highest mean weight: ***Curcuma longa*** (427.81 mg)
#
# Species with lowest mean weight: ***Rosmarinus officinalis*** (386.61 mg)
#
# **Notable pattern:**
#
# "Rosmarinus samples tended to be lighter across sample types, while Curcuma had more heavy samples."
#
# 4. **Crosstab Summary (Sample Type × pH Category)**
#
# ***Rosmarinus officinalis*** had the highest percentage of acidic samples, with a low marginal difference.
# Generaly all species showed a higher percentage of acidic species as compared to the other pH categories.
#
#
# 5. **Visualization Insights**
#
# **Histogram of pH:**
# -The pH distribution shows two peaks: one around pH 5 (acidic) and another near pH 8 (basic). Neutral samples were relatively fewer.
# -This suggests that the herbal samples tend to fall into either acidic or basic pH ranges, with acidic samples being slightly more dominant.
#
# 6. **Grouped bar chart:**
# All four species have similar average weights (≈ 380–430 mg).
#
# However, two species stand out slightly:
#
# ***Curcuma longa*** (leftmost) appears to have the highest mean weight.
#
# ***Lavandula angustifolia*** looks slightly lower but still close to others.
#
# 7. **Outlier Detection**
#
# Criteria for outliers:
#
# weight_mg > 700
#
# OR pH < 4.5
#
# OR pH > 8.2
#
# Report:
#
# Number of outliers: 37
#
# species that  had the most outliers:
# Lavandula angustifolia    10
# Rosmarinus officinalis    10
# Interpretation:
#
# ***Lavundula*** and ***Rosmarinus*** had the most heavy outliers due to naturally dense rhizome samples."
#
# 8. **Stability Index Analysis**
#
# Formula:
#
# stability_index = weight_grams * pH
#
# root samples showed a high stability index.
#
#
# Interpretation:
#
# Root samples showed higher stability indices, possibly due to their higher biomass and consistent pH."
#
# ⭐ 9. Overall Insights & Conclusions
#
#
# “Root samples tended to show the widest pH variation.”
#
# “Lavundula species consistently had heavier samples and higher stability indices.”
#
# “Lavender shows a shift toward higher pH, making it the least acidic species.”
#
# “The dataset behaved biologically realistically, supporting valid interpretation.”
#
# ⭐ 10. Deliverables Completed
#
# -Data loading and overview
#
# -Filtering tasks
#
# -Feature engineering
#
# -Crosstabs and grouping
#
# -Visualizations
#
# -Outlier analysis
#
# -Summary statistics
#
# -Percentage table
#
# -Stability index creation
#
# -Final mini-report/insights
